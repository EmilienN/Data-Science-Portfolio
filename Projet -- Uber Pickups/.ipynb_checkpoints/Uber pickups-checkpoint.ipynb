# %% [markdown]
# # Unsupervised Learning Machine
#
#
# <img align="left"  src="traffic-in-times-square--new-york-city-77817998-5c2e88c146e0fb00013a2772.jpg" alt="drawing" style="width:400px;"/>

# %% [markdown]
# ## Project
# ### Using KMeans for Uber Trips
#
# In this project, you will see the power of KMeans in today's world. Imagine that you are Uber and you want to give recommendations as to where drivers should be in order to maximize their chances of finding a race.
#
# We will use the Machine Learning to create this recommendation algorithm.
#
# Take the following dataset: uber-trip-data
#
#   1. Try to see the optimum number of clusters
#   2. Find these clusters on a map
#   3. Now separate these clusters according to the time of day
#   4. See the difference between KMeans and DBSCAN

# %% [markdown]
# Header | Definition
# ---|---------
# `Date/Time` | The date and time of the Uber pickup
# `Lat` | The latitude of the Uber pickup
# `Lon` | The longitude of the Uber pickup
# `Base` | The [TLC base company](http://www.nyc.gov/html/tlc/html/industry/base_and_business.shtml) code affiliated with the Uber pickup

# %% [markdown]
# ## Table of Contents <a class="anchor" id="0"></a>
#
# I.   [Data exploration](#1)<br/>
#
#
# II.  [Clustering](#2)<br/>
#
#    1.  [MiniBatchKmeans](#2a) <br/>
#    2.  [Empirical evaluation of the impact of k-means initializationDBSCAN](#2b)<br/>
#    3.  [Time](#2c)<br/>
#    4.  [DBSCANh](#2d)<br/>
#
# III. [ARIMA Model](#3)<br/>
#
# IV.  [SARIMA Model](#3)<br/>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#Bokeh
from bokeh.io import export_png
from bokeh.io import output_file, show
from bokeh.models import ColumnDataSource, GMapOptions
from bokeh.plotting import gmap

#Matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter

#Seaborn
import seaborn as sns

import random
import time
from tqdm import tqdm

# Import augmented dicky-fuller test function
from statsmodels.tsa.stattools import adfuller

# Import statsmodels
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima_model import ARIMA

# Import pmdarima as pm
import pmdarima as pm

from scipy.stats import norm
import statsmodels.api as sm

# %% [markdown]
# # Data exploration <a class="anchor" id="1"></a>
# [return to contents](#0)

# %%
#Loading the Spatial Dataset

dataset = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight\
/uber-tlc-foil-response/master/uber-trip-data/uber-raw-data-apr14.csv")

# %%
#Taking a look at the dataset
dataset.head()
# Out:
#           Date/Time      Lat      Lon    Base
# 0  4/1/2014 0:11:00  40.7690 -73.9549  B02512
# 1  4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2  4/1/2014 0:21:00  40.7316 -73.9873  B02512
# 3  4/1/2014 0:28:00  40.7588 -73.9776  B02512
# 4  4/1/2014 0:33:00  40.7594 -73.9722  B02512

# %%
dataset.Base.value_counts()
# Out:
# B02682    227808
# B02598    183263
# B02617    108001
# B02512     35536
# B02764      9908
# Name: Base, dtype: int64

# %%
#Taking information 
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 564516 entries, 0 to 564515
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date/Time  564516 non-null  object
#  1   Lat        564516 non-null  float64
#  2   Lon        564516 non-null  float64
#  3   Base       564516 non-null  object
# dtypes: float64(2), object(2)
# memory usage: 17.2+ MB

# %%
#Preparing the Spatial Dataset
X=dataset[['Lat','Lon']]

# %%
#Define the Bounding Box
BBox = ((dataset.Lon.min(),   dataset.Lon.max(),      
         dataset.Lat.min(), dataset.Lat.max()))
BBox
# Out:
# (-74.7733, -72.0666, 40.0729, 42.1166)

# %% [markdown]
# # Clustering <a class="anchor" id="2"></a>
# [return to contents](#0)

# %% [markdown]
# ## MiniBatchKmeans <a class="anchor" id="2a"></a>
# [return to contents](#0)

# %%
X= X.sample(30000)

# %%
n_clusters=6
from sklearn.cluster import MiniBatchKMeans
kmeans = MiniBatchKMeans(n_clusters)
kmeans.fit(X)
# Out:
# MiniBatchKMeans(batch_size=100, compute_labels=True, init='k-means++',
#                 init_size=None, max_iter=100, max_no_improvement=10,
#                 n_clusters=6, n_init=3, random_state=None,
#                 reassignment_ratio=0.01, tol=0.0, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 40.73613582, -73.99544315],
#        [ 40.71953162, -74.00034036],
#        [ 40.69901937, -74.20759319],
#        [ 40.77110538, -73.96164117],
#        [ 40.68827243, -73.9653963 ],
#        [ 40.66478449, -73.78317843]])

# %%
map_options = GMapOptions(lat=40.7128, lng=-74.0060, map_type="roadmap", zoom=10)
c = gmap("AIzaSyB-E81VWnuGE2A9iXgHHI3lz5ZOvbRIN3A", map_options, title="New York")

centroid = ColumnDataSource(data=dict(lat=kmeans.cluster_centers_[:,0],
                                      lon=kmeans.cluster_centers_[:,1]))
cluster_X_kmeans = list()


for i in range(n_clusters):
    cluster_X_kmeans.append(ColumnDataSource(data=dict(lat=X[kmeans.labels_== i].iloc[:,0],
                                             lon=X[kmeans.labels_== i].iloc[:,1])))
    
    couleurs = ["#"+''.join([random.choice('0123456789ABCDEF') for i in range(6)]) for j in range(n_clusters)]

    c.circle(x="lon", y="lat", size=4, color=couleurs[i], fill_alpha=0.5, source=cluster_X_kmeans[i])

# %%
c.circle(x="lon",
         y="lat", 
         size=20, 
         fill_color="yellow", 
         fill_alpha=0.8, source=centroid)
# Out:
# GlyphRenderer(id='1068', ...)

# %%
#Save map image 
export_png(c, filename="map.png")
# Out:
# 'C:\\Users\\kaill\\jedha-projet\\Projet -- Uber Pickups (In progress)\\map.png'

# %%
#Take a look 

img=mpimg.imread("map.png")
img2= mpimg.imread("carte-plan-new-york-arrondissements-boroughs-630x616.jpeg")
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10)) 
plt.imshow(img)

plt.show()
plt.figure(figsize=(20,10)) 
plt.imshow(img2)
plt.show()

# %% [markdown]
# ## Empirical evaluation of the impact of k-means initialization <a class="anchor" id="2b"></a>
# [return to contents](#0)

# %% [markdown]
# ### Elbow method

# %%
kmeans.inertia_
# Out:
# 39.38077054245787

# %%
inertias = []

for k in range(1, 20):
        kmeans = MiniBatchKMeans(n_clusters=k)
        kmeans.fit(X)
        inertias.append(kmeans.inertia_)

# %%
sns.lineplot(x=range(1, 20), y=inertias)

# %% [markdown]
# ### Silhouette

# %%
from sklearn.metrics import silhouette_score

silhouette_list_kmeans= []
for i in tqdm(range(2,15)):
    kmeans_silhouettex = MiniBatchKMeans(n_clusters=i)
    kmeans_silhouettex.fit(X)
    silhouette_list_kmeans.append(silhouette_score(X, kmeans_silhouettex.labels_))
    time.sleep(1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 13/13 [03:30<00:00, 16.19s/it]

# %%
sns.lineplot(range(2,15),silhouette_list_kmeans)

# %%
index_silhouette = np.where(silhouette_list_kmeans[1:15] == max(silhouette_list_kmeans[1:15]))

# Best n clusters_silhoutte
best_n_clusters_silhouette = index_silhouette[0][0]+3
best_n_clusters_silhouette
# Out:
# 3

# %% [markdown]
# ## Time <a class="anchor" id="2c"></a>
# [return to contents](#0)

# %%
from datetime import datetime
#converting Date/Time column to datetime 
dataset['Date/Time'] =  pd.to_datetime(dataset['Date/Time'], format='%m/%d/%Y %H:%M:%S')
#extracting the Hour from Date/Time column and putting it into a new column named 'Hour'
dataset['Hour'] = dataset['Date/Time'].apply(lambda x: x.hour)
#extracting the Minute from Date/Time column and putting it into a new column named 'Minute'
dataset['Minute'] = dataset['Date/Time'].apply(lambda x: x.minute)
#extracting the Month from Date/Time column and putting it into a new column named 'Month'
dataset['Month'] = dataset['Date/Time'].apply(lambda x: x.month)
#extracting the Day from Date/Time column and putting it into a new column named 'Day'
dataset['Day'] = dataset['Date/Time'].apply(lambda x: x.day)
#extracting the Weekday from Date/Time column and putting it into a new column named 'Day'
dataset['Weekday'] = dataset['Date/Time'].apply(lambda x: x.strftime('%A'))

# %%
# Uber pickups by the hour in NYC
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
ax = sns.countplot(x="Hour", data=dataset, color="lightsteelblue")
ax.yaxis.set_major_formatter(FormatStrFormatter('%.0f'))
ax.set_xlabel('Hour of the Day', fontsize = 12)
ax.set_ylabel('Count of Uber Pickups', fontsize = 12)
ax.set_title('Uber Pickups By the Hour in NYC (Apr 2014)', fontsize=16)
ax.tick_params(labelsize = 8)
plt.show()

# %%
X1=dataset[dataset['Hour']==17].drop(columns = ["Date/Time","Base","Hour",'Month','Day','Weekday'])

# %%
X1['Lat'].value_counts().sum()
# Out:
# 45475

# %% [markdown]
# ## DBSCAN <a class="anchor" id="2d"></a>
# [return to contents](#0)

# %%
from sklearn.cluster import DBSCAN
clusters = DBSCAN(eps=0.899, min_samples=500)
clusters.fit_predict(X1)
# Out:
# array([ 0,  0,  1, ..., 41, 58, 43], dtype=int64)

# %%
n= len(np.unique(clusters.labels_))
print(n)

cluster_X_DBSCAN = list()
couleurs=list()
# Out:
# 60

# %%
map_options = GMapOptions(lat=40.7128, lng=-74.0060, map_type="roadmap", zoom=10)
p = gmap("AIzaSyB-E81VWnuGE2A9iXgHHI3lz5ZOvbRIN3A", map_options, title="New York")
                        
for i in range(n):
    cluster_X_DBSCAN.append(ColumnDataSource(data=dict(lat=X1[clusters.labels_== i].iloc[:,0],
                                                       lon=X1[clusters.labels_== i].iloc[:,1])))
    couleurs.append(["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6) ]) for j in range(n)])
    p.circle(x="lon", y="lat", size=4, color=couleurs[i][i], fill_alpha=0.8, source=cluster_X_DBSCAN[i])

# %%
cluster_X_DBSCAN.append(ColumnDataSource(data=dict(lat=X1[clusters.labels_==-1].iloc[:,0],
              lon=X1[clusters.labels_==-1].iloc[:,1]
             )))

# %%
p.circle(x="lon",
             y="lat", 
             size=8, 
             color='#E65BA9', 
             fill_alpha=0.8, source=cluster_X_DBSCAN[n])
# Out:
# GlyphRenderer(id='1693', ...)

# %%
from bokeh.io import export_png
export_png(p, filename="map_DBSCAN.png")
# Out:
# WARNING:bokeh.io.export:The webdriver raised a TimeoutException while waiting for a 'bokeh:idle' event to signify that the layout has rendered. Something may have gone wrong.
# 'C:\\Users\\kaill\\jedha-projet\\Projet -- Uber Pickups (In progress)\\map_DBSCAN.png'

# %%
#Take a look 

img=mpimg.imread("map_DBSCAN.png")

import matplotlib.pyplot as plt
plt.figure(figsize=(20,10)) 
plt.imshow(img)

# %%
#optimal value for epsilon

from sklearn.neighbors import NearestNeighbors
neigh = NearestNeighbors(n_neighbors=2)
nbrs = neigh.fit(X1)
distances, indices = nbrs.kneighbors(X1)
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)

# %% [markdown]
# # ARIMA Model <a class="anchor" id="3"></a>
# [return to contents](#0)

# %%
dataset
# Out:
#                  Date/Time      Lat      Lon    Base  Hour  Minute  Month  \
# 0      2014-04-01 00:11:00  40.7690 -73.9549  B02512     0      11      4
# 1      2014-04-01 00:17:00  40.7267 -74.0345  B02512     0      17      4
# 2      2014-04-01 00:21:00  40.7316 -73.9873  B02512     0      21      4
# 3      2014-04-01 00:28:00  40.7588 -73.9776  B02512     0      28      4
# 4      2014-04-01 00:33:00  40.7594 -73.9722  B02512     0      33      4
# ...                    ...      ...      ...     ...   ...     ...    ...
# 564511 2014-04-30 23:22:00  40.7640 -73.9744  B02764    23      22      4
# 564512 2014-04-30 23:26:00  40.7629 -73.9672  B02764    23      26      4
# 564513 2014-04-30 23:31:00  40.7443 -73.9889  B02764    23      31      4
# 564514 2014-04-30 23:32:00  40.6756 -73.9405  B02764    23      32      4
# 564515 2014-04-30 23:48:00  40.6880 -73.9608  B02764    23      48      4
#
#         Day    Weekday
# 0         1    Tuesday
# 1         1    Tuesday
# 2         1    Tuesday
# 3         1    Tuesday
# 4         1    Tuesday
# ...     ...        ...
# 564511   30  Wednesday
# 564512   30  Wednesday
# 564513   30  Wednesday
# 564514   30  Wednesday
# 564515   30  Wednesday
#
# [564516 rows x 9 columns]

# %%
df= dataset

# Grouping by Date/Timer_ to calculate number of trips
hour_df= pd.Series(df.groupby(['Date/Time']).size())
# setting Date/Time as index
hour_df.index = pd.DatetimeIndex(hour_df.index)
# Resampling to hour trips
hour_df = hour_df.resample('1H').apply(np.sum)

hour_df= hour_df.loc[:'2014-04-30 00:00:00']

hour_df
# Out:
# Date/Time
# 2014-04-01 00:00:00     138
# 2014-04-01 01:00:00      66
# 2014-04-01 02:00:00      53
# 2014-04-01 03:00:00      93
# 2014-04-01 04:00:00     166
#                        ...
# 2014-04-29 20:00:00    1666
# 2014-04-29 21:00:00    1575
# 2014-04-29 22:00:00     808
# 2014-04-29 23:00:00     456
# 2014-04-30 00:00:00     219
# Freq: H, Length: 697, dtype: int64

# %% [markdown]
# ### Identification

# %%
# Plot time series
hour_df.plot()
plt.show()

# %%
# Run Dicky-Fuller test
result = adfuller(hour_df)

# Print test statistic
print(result[0])

# Print p-value
print(result[1])
# Out:
# -3.6719941397915203
# 0.0045247782351378685

# %% [markdown]
# ### Identification II

# %%
# Create figure
fig, (ax1, ax2) = plt.subplots(2,1, figsize=(12,8))
 
# Plot the ACF of savings on ax1
plot_acf(hour_df, lags=48, zero=False, ax=ax1)

# Plot the PACF of savings on ax2
plot_pacf(hour_df, lags=48, zero=False, ax=ax2)

plt.show()

# %% [markdown]
# ### Estimation

# %%
## Searching over model order
import warnings
warnings.filterwarnings("ignore")
# Create empty list to store search results
order_aic_bic=[]

# Loop over p values from 0-2
for p in range(6):
  # Loop over q values from 0-2
    for q in range(18):
        # create and fit ARMA(p,q) model
        model = SARIMAX(hour_df, order=(p,0,q), trend='c')
        results = model.fit()
        
        # Append order and results tuple
        order_aic_bic.append((p, q, results.aic, results.bic))
        

# In the next exercise you will evaluate the results to choose the best model.

# %%
## Choosing order with AIC and BIC

#Construct DataFrame from order_aic_bic
order_df = pd.DataFrame(order_aic_bic, 
                        columns=['p','q', 'AIC', 'BIC'])

# Print order_df in order of increasing AIC
print(order_df.sort_values('AIC'))

# Print order_df in order of increasing BIC
print(order_df.sort_values('BIC'))
# Out:
#      p   q           AIC           BIC
# 106  5  16   8993.639245   9098.215309
# 107  5  17   8994.104311   9103.227161
# 105  5  15   8996.514732   9096.544011
# 101  5  11   9001.725295   9083.567433
# 89   4  17   9018.483828   9123.059893
# ..  ..  ..           ...           ...
# 2    0   2   9477.961376   9496.148518
# 10   0  10   9694.898006   9749.459431
# 12   0  12   9735.796427   9799.451423
# 1    0   1   9902.395422   9916.035778
# 0    0   0  10648.218447  10657.312018
#
# [108 rows x 4 columns]
#      p   q           AIC           BIC
# 101  5  11   9001.725295   9083.567433
# 105  5  15   8996.514732   9096.544011
# 106  5  16   8993.639245   9098.215309
# 107  5  17   8994.104311   9103.227161
# 78   4   6   9052.035790   9106.597215
# ..  ..  ..           ...           ...
# 2    0   2   9477.961376   9496.148518
# 10   0  10   9694.898006   9749.459431
# 12   0  12   9735.796427   9799.451423
# 1    0   1   9902.395422   9916.035778
# 0    0   0  10648.218447  10657.312018
#
# [108 rows x 4 columns]

# %%
# Instantiate the model
model = SARIMAX(hour_df, order=(4,0,16))

# Fit the model
results = model.fit()

# Print summary
print(results.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  697
# Model:              SARIMAX(4, 0, 16)   Log Likelihood               -4523.729
# Date:                Mon, 13 Apr 2020   AIC                           9089.458
# Time:                        14:05:30   BIC                           9184.941
# Sample:                    04-01-2014   HQIC                          9126.375
#                          - 04-30-2014
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          2.4606      0.233     10.580      0.000       2.005       2.916
# ar.L2         -1.9929      0.634     -3.144      0.002      -3.235      -0.750
# ar.L3          0.2704      0.633      0.427      0.669      -0.969       1.510
# ar.L4          0.2616      0.231      1.132      0.258      -0.191       0.715
# ma.L1         -1.0430      0.227     -4.603      0.000      -1.487      -0.599
# ma.L2         -0.0867      0.307     -0.282      0.778      -0.689       0.516
# ma.L3          0.3628      0.087      4.176      0.000       0.192       0.533
# ma.L4          0.2561      0.083      3.099      0.002       0.094       0.418
# ma.L5         -0.1087      0.071     -1.535      0.125      -0.247       0.030
# ma.L6         -0.0638      0.069     -0.925      0.355      -0.199       0.071
# ma.L7         -0.0074      0.058     -0.127      0.899      -0.121       0.107
# ma.L8         -0.0968      0.059     -1.646      0.100      -0.212       0.018
# ma.L9          0.0293      0.070      0.421      0.674      -0.107       0.166
# ma.L10         0.1131      0.060      1.872      0.061      -0.005       0.232
# ma.L11        -0.0552      0.068     -0.808      0.419      -0.189       0.079
# ma.L12        -0.2358      0.065     -3.627      0.000      -0.363      -0.108
# ma.L13        -0.0726      0.071     -1.026      0.305      -0.211       0.066
# ma.L14         0.2146      0.054      3.952      0.000       0.108       0.321
# ma.L15         0.0633      0.077      0.822      0.411      -0.088       0.214
# ma.L16        -0.2381      0.063     -3.807      0.000      -0.361      -0.115
# sigma2      2.469e+04   1111.742     22.207      0.000    2.25e+04    2.69e+04
# ===================================================================================
# Ljung-Box (Q):                      247.60   Jarque-Bera (JB):               264.10
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.83   Skew:                            -0.10
# Prob(H) (two-sided):                  0.16   Kurtosis:                         6.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### Forecasting

# %%
# Generate predictions
dynamic_forecast = results.get_prediction(start=-24, dynamic=True)

# Extract prediction mean
mean_forecast = dynamic_forecast.predicted_mean

# Get confidence intervals of predictions
confidence_intervals = dynamic_forecast.conf_int()

# Select lower and upper confidence limits
lower_limits = confidence_intervals.loc[:,'lower y']
upper_limits = confidence_intervals.loc[:,'upper y']

# Print best estimate predictions
print(mean_forecast.head())
# Out:
# Date/Time
# 2014-04-29 01:00:00     99.026651
# 2014-04-29 02:00:00    161.920596
# 2014-04-29 03:00:00    298.499940
# 2014-04-29 04:00:00    387.731683
# 2014-04-29 05:00:00    480.983456
# Freq: H, dtype: float64

# %%
hour_df1= hour_df.loc['2014-04-15 23:00:00':]


## Plotting one-step-ahead predictions
plt.figure(figsize=(20,10))
# plot the amazon data
plt.plot(hour_df1.index, hour_df1, label='observed')


# plot your mean predictions
plt.plot(mean_forecast.index, mean_forecast, color='r', label='forecast')

# shade the area between your confidence limits
plt.fill_between(lower_limits.index, 
                 lower_limits,
                 upper_limits, color='pink')

# set labels, legends and show plot
plt.xlabel('Date')
plt.ylabel('Number of Uber Trips')

plt.legend()
plt.show()

# %%
# Calculate the mean absolute error from residuals
mae = np.mean(np.abs(results.resid))

# Print mean absolute error
print(mae)
# Out:
# 115.87145418907923

# %% [markdown]
# ## SARIMA Model <a class="anchor" id="4"></a>
# [return to contents](#0)

# %% [markdown]
# ### Estimation

# %%
# Create model for SARIMAX(p,1,q)(P,1,Q)7
model3 = pm.auto_arima(hour_df,
                      seasonal=True, m=24,
                      d=0, D=0, 
                      start_p=1, start_q=1,
                      max_p=4, max_q=4,
                      max_P=4, max_Q=4,
                      trace=True,
                      error_action='ignore',
                      suppress_warnings=True, n_jobs=-1) 

# Print model summary
print(model3.summary())
# Out:
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 0, 1, 24); AIC=8891.084, BIC=8918.365, Fit time=4.181 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 0, 24); AIC=10648.218, BIC=10657.312, Fit time=0.020 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 0, 24); AIC=9066.523, BIC=9084.710, Fit time=3.610 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 1, 24); AIC=9619.756, BIC=9637.944, Fit time=1.902 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 0, 1, 24); AIC=9048.308, BIC=9071.042, Fit time=2.645 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(2, 0, 1, 24); AIC=8899.836, BIC=8931.664, Fit time=20.147 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 0, 0, 24); AIC=8984.024, BIC=9006.758, Fit time=4.794 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 0, 2, 24); AIC=8908.723, BIC=8940.551, Fit time=21.782 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 0, 0, 24); AIC=9200.240, BIC=9218.427, Fit time=0.452 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(2, 0, 2, 24); AIC=8911.212, BIC=8947.587, Fit time=27.461 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(1, 0, 1, 24); AIC=9549.414, BIC=9572.148, Fit time=4.408 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 0, 1, 24); AIC=8959.728, BIC=8991.556, Fit time=4.573 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 1, 24); AIC=9009.532, BIC=9032.265, Fit time=4.185 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(1, 0, 1, 24); AIC=8914.084, BIC=8945.912, Fit time=5.069 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(1, 0, 1, 24); AIC=10148.178, BIC=10166.365, Fit time=2.900 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 0, 1, 24); AIC=8982.783, BIC=9019.158, Fit time=5.973 seconds
# Total fit time: 114.109 seconds
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  697
# Model:             SARIMAX(1, 0, 1)x(1, 0, 1, 24)   Log Likelihood               -4439.542
# Date:                            Mon, 13 Apr 2020   AIC                           8891.084
# Time:                                    14:07:51   BIC                           8918.365
# Sample:                                         0   HQIC                          8901.632
#                                             - 697
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.7260      0.522      1.392      0.164      -0.297       1.749
# ar.L1          0.8283      0.016     51.372      0.000       0.797       0.860
# ma.L1          0.4029      0.027     15.031      0.000       0.350       0.455
# ar.S.L24       0.9934      0.004    250.800      0.000       0.986       1.001
# ma.S.L24      -0.9033      0.030    -30.508      0.000      -0.961      -0.845
# sigma2      1.791e+04    706.631     25.347      0.000    1.65e+04    1.93e+04
# ===================================================================================
# Ljung-Box (Q):                      168.72   Jarque-Bera (JB):               322.50
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.90   Skew:                             0.20
# Prob(H) (two-sided):                  0.43   Kurtosis:                         6.31
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Create model object
model1 = SARIMAX(hour_df, 
                order=(1, 0, 1),  
                seasonal_order=(1, 0, 1, 24))
# Fit model
results_sarimax = model1.fit()

# %%
# Plot common diagnostics
results_sarimax.plot_diagnostics()
plt.show()

# %% [markdown]
# ### Forecasting

# %%
# Generate predictions
dynamic_forecast = results_sarimax.get_prediction(start=-48, dynamic=True)

# Extract prediction mean
mean_forecast = dynamic_forecast.predicted_mean

# Get confidence intervals of predictions
confidence_intervals = dynamic_forecast.conf_int()

# Select lower and upper confidence limits
lower_limits = confidence_intervals.loc[:,'lower y']
upper_limits = confidence_intervals.loc[:,'upper y']

# Print best estimate predictions
print(mean_forecast.head())
# Out:
# Date/Time
# 2014-04-28 01:00:00    106.266942
# 2014-04-28 02:00:00     30.929095
# 2014-04-28 03:00:00     48.089672
# 2014-04-28 04:00:00     93.811591
# 2014-04-28 05:00:00    204.519366
# Freq: H, dtype: float64

# %%
## Plotting one-step-ahead predictions
plt.figure(figsize=(20,10))
# plot the amazon data
plt.plot(hour_df1.index, hour_df1, label='observed')


# plot your mean predictions
plt.plot(mean_forecast.index, mean_forecast, color='r', label='forecast')

# shade the area between your confidence limits
plt.fill_between(lower_limits.index, 
                 lower_limits,
                 upper_limits, color='pink')

# set labels, legends and show plot
plt.xlabel('Date')
plt.ylabel('Number of Uber Trips')

plt.legend()
plt.show()

# %%
# Calculate the mean absolute error from residuals
mae = np.mean(np.abs(results_sarimax.resid))

# Print mean absolute error
print(mae)
# Out:
# 99.53476889872056
